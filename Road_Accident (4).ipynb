# %% [markdown]
# # Road Accident

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\DISHA PODHA\Documents\data analyst\My_data.xlsx.xlsx")

# %%
data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
data.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
for value in ['Educational_level','Vehicle_driver_relation','Driving_experience','Type_of_vehicle','Owner_of_vehicle','Service_year_of_vehicle','Defect_of_vehicle','Area_accident_occured','Lanes_or_Medians','Road_allignment','Types_of_Junction','Road_surface_type','Type_of_collision','Vehicle_movement','Work_of_casuality','Fitness_of_casuality']:
              data[value].fillna(data[value][4],inplace=True)

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                 950
# Owner_of_vehicle                  0
# Service_year_of_vehicle           0
# Defect_of_vehicle                 0
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction                 0
# Road_surface_type                 0
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision                 0
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                  0
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
for value in ['Fitness_of_casuality']:
              data[value].fillna(data[value][5],inplace=True)

# %%
for value in ['Work_of_casuality']:
              data[value].fillna(data[value][5],inplace=True)

# %%
data.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                950
# Owner_of_vehicle                 0
# Service_year_of_vehicle          0
# Defect_of_vehicle                0
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Types_of_Junction                0
# Road_surface_type                0
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement                 0
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# ...

# %%
for value in ['Type_of_vehicle']:
              data[value].fillna(data[value][2],inplace=True)

# %%
data.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
for i in data.columns:
    print(i,':','\n',data[i].unique())
# Out:
# Time :
#  ['17:02:00' '1:06:00' '14:15:00' ... '7:24:00' '19:18:00' '2:47:00']
# Day_of_week :
#  ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
# Age_band_of_driver :
#  ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# Sex_of_driver :
#  ['Male' 'Female' 'Unknown']
# Educational_level :
#  ['Above high school' 'Junior high school' 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
# Vehicle_driver_relation :
#  ['Employee' 'Unknown' 'Owner' 'Other']
# Driving_experience :
#  ['1-2yr' 'Above 10yr' '5-10yr' '2-5yr' 'No Licence' 'Below 1yr' 'unknown']
# Type_of_vehicle :
#  ['Automobile' 'Public (> 45 seats)' 'Lorry (41?100Q)'
#  'Public (13?45 seats)' 'Lorry (11?40Q)' 'Long lorry' 'Public (12 seats)'
#  'Taxi' 'Pick up upto 10Q' 'Stationwagen' 'Ridden horse' 'Other' 'Bajaj'
#  'Turbo' 'Motorcycle' 'Special vehicle' 'Bicycle']
# Owner_of_vehicle :
#  ['Owner' 'Governmental' 'Organization' 'Other']
# Service_year_of_vehicle :
# ...

# %%
for value in data.columns:
    print(value,':',sum(data[value]=='?'))
# Out:
# Time : 0
# Day_of_week : 0
# Age_band_of_driver : 0
# Sex_of_driver : 0
# Educational_level : 0
# Vehicle_driver_relation : 0
# Driving_experience : 0
# Type_of_vehicle : 0
# Owner_of_vehicle : 0
# Service_year_of_vehicle : 0
# Defect_of_vehicle : 0
# Area_accident_occured : 0
# Lanes_or_Medians : 0
# Road_allignment : 0
# Types_of_Junction : 0
# Road_surface_type : 0
# Road_surface_conditions : 0
# Light_conditions : 0
# Weather_conditions : 0
# Type_of_collision : 0
# Number_of_vehicles_involved : 0
# Number_of_casualties : 0
# Vehicle_movement : 0
# Casualty_class : 0
# Sex_of_casualty : 0
# Age_band_of_casualty : 0
# Casualty_severity : 0
# Work_of_casuality : 0
# Fitness_of_casuality : 0
# Pedestrian_movement : 0
# Cause_of_accident : 0
# Accident_severity : 0

# %%
sns.barplot(x=data.Accident_severity,y=data.Number_of_casualties)
plt.title('Number of Casualties by Accident Severity')
# Out:
# Text(0.5, 1.0, 'Number of Casualties by Accident Severity')

# %%
sns.countplot(x=data.Fitness_of_casuality,hue=data.Accident_severity)
plt.title('Count of Casualties By Accident Severity')
# Out:
# Text(0.5, 1.0, 'Count of Casualties By Accident Severity')

# %%
sns.countplot(x=data.Day_of_week,hue=data.Accident_severity)
plt.title('Distribution of Accident Severity by Day of the Week')
# Out:
# Text(0.5, 1.0, 'Distribution of Accident Severity by Day of the Week')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=data.Work_of_casuality,hue=data.Accident_severity)
plt.title('Distribution of Accident Severity by Occupations of Casualties')
# Out:
# Text(0.5, 1.0, 'Distribution of Accident Severity by Occupations of Casualties')

# %%
sns.countplot(x=data.Casualty_class,hue=data.Accident_severity)
plt.title('Distribution of Casualty Class by Accident Severity')
# Out:
# Text(0.5, 1.0, 'Distribution of Casualty Class by Accident Severity')

# %%
sns.countplot(x=data.Sex_of_casualty,hue=data.Accident_severity)
plt.title('Accident Severity by Gender')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Gender')

# %%
sns.countplot(x=data.Age_band_of_casualty,hue=data.Accident_severity)
plt.title('Distribution of Accident Severity by Age of Casualty')
# Out:
# Text(0.5, 1.0, 'Distribution of Accident Severity by Age of Casualty')

# %%
sns.countplot(x=data.Sex_of_driver,hue=data.Accident_severity)
plt.title('Accident Severity by Sex of Driver')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Sex of Driver')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Educational_level,hue=data.Accident_severity)
plt.title('Accident Severity by Education Level of Casualties')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Education Level of Casualties')

# %%
sns.countplot(x=data.Vehicle_driver_relation,hue=data.Accident_severity)
plt.title('Accident Severity by Relation of Vehicle')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Relation of Vehicle')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Driving_experience,hue=data.Accident_severity)
plt.title('Accident Severity by Driving Experience')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Driving Experience')

# %%
plt.figure(figsize=(28,15))
sns.countplot(x=data.Type_of_vehicle,hue=data.Accident_severity)
plt.title('Accident Severity According to Type of Vehicle')
# Out:
# Text(0.5, 1.0, 'Accident Severity According to Type of Vehicle')

# %%
sns.countplot(x=data.Owner_of_vehicle,hue=data.Accident_severity)
plt.title('Accident Severity by Owner of Vehicle')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Owner of Vehicle')

# %%
sns.countplot(x=data.Service_year_of_vehicle,hue=data.Accident_severity)
plt.title('Accident Severity by Service Year of Vehicle ')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Service Year of Vehicle ')

# %%
sns.countplot(x=data.Defect_of_vehicle,hue=data.Accident_severity)
plt.title('Accident Severity by Defect of Vehicle')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Defect of Vehicle')

# %%
plt.figure(figsize=(32,10))
sns.countplot(x=data.Area_accident_occured,hue=data.Accident_severity)
plt.title('Accident Severity by Area of Accident')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Area of Accident')

# %%
plt.figure(figsize=(32,10))
sns.countplot(x=data.Lanes_or_Medians,hue=data.Accident_severity)
plt.title('Accident Severity according to Lanes or Meadians')
# Out:
# Text(0.5, 1.0, 'Accident Severity according to Lanes or Meadians')

# %%
plt.figure(figsize=(40,30))
sns.countplot(x=data.Road_allignment ,hue=data.Accident_severity)
plt.title('Accident Severity by Allingment of Road')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Allingment of Road')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Types_of_Junction ,hue=data.Accident_severity)
plt.title('Accident Severity by Junction Types ')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Junction Types ')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Road_surface_type ,hue=data.Accident_severity)
plt.title('Accident Severity by Road Surface Type')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Road Surface Type')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Road_surface_conditions,hue=data.Accident_severity)
plt.title('Accident Severity by Road Surface Condition')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Road Surface Condition')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Light_conditions ,hue=data.Accident_severity)
plt.title('Accident Severity by Light Conditions')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Light Conditions')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Weather_conditions ,hue=data.Accident_severity)
plt.title('Accident Severity by Weather Conditions')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Weather Conditions')

# %%
plt.figure(figsize=(35,10))
sns.countplot(x=data.Type_of_collision ,hue=data.Accident_severity)
plt.title('Accident Severity by Type of Collision')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Type of Collision')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Number_of_vehicles_involved ,hue=data.Accident_severity)
plt.title('Accident Severity by Vehicles Involved')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Vehicles Involved')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Number_of_casualties,hue=data.Accident_severity)
plt.title('Accident Severity Considering Number of Casualty')
# Out:
# Text(0.5, 1.0, 'Accident Severity Considering Number of Casualty')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Vehicle_movement,hue=data.Accident_severity)
plt.title('Accident Severity by Vehicle Movement')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Vehicle Movement')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=data.Casualty_severity,hue=data.Accident_severity)
plt.title('Accident Severity by Casualty Severity')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Casualty Severity')

# %%
plt.figure(figsize=(50,10))
sns.countplot(x=data.Cause_of_accident,hue=data.Accident_severity)
plt.title('Accident Severity by Cause of Accident')
# Out:
# Text(0.5, 1.0, 'Accident Severity by Cause of Accident')

# %%
#encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data.Time=le.fit_transform(data.Time)

# %%
le1=LabelEncoder()
data.Day_of_week =le1.fit_transform(data.Day_of_week )

# %%
le2=LabelEncoder()
data.Age_band_of_driver=le2.fit_transform(data.Age_band_of_driver)

# %%
le3=LabelEncoder()
data.Sex_of_driver=le3.fit_transform(data.Sex_of_driver)

# %%
le4=LabelEncoder()
data.Educational_level=le4.fit_transform(data.Educational_level)

# %%
le5=LabelEncoder()
data.Vehicle_driver_relation=le5.fit_transform(data.Vehicle_driver_relation)

# %%
le6=LabelEncoder()
data.Driving_experience=le6.fit_transform(data.Driving_experience)

# %%
le7=LabelEncoder()
data.Type_of_vehicle=le7.fit_transform(data.Type_of_vehicle)

# %%
le8=LabelEncoder()
data.Owner_of_vehicle=le8.fit_transform(data.Owner_of_vehicle)

# %%
le9=LabelEncoder()
data.Service_year_of_vehicle =le9.fit_transform(data.Service_year_of_vehicle )

# %%
le10=LabelEncoder()
data.Defect_of_vehicle =le10.fit_transform(data.Defect_of_vehicle )

# %%
le11=LabelEncoder()
data.Area_accident_occured =le11.fit_transform(data.Area_accident_occured )

# %%
le12=LabelEncoder()
data.Lanes_or_Medians =le12.fit_transform(data.Lanes_or_Medians)

# %%
le13=LabelEncoder()
data.Road_allignment =le13.fit_transform(data.Road_allignment)

# %%
le14=LabelEncoder()
data.Types_of_Junction =le14.fit_transform(data.Types_of_Junction )

# %%
le15=LabelEncoder()
data.Road_surface_type  =le15.fit_transform(data.Road_surface_type  )

# %%
le16=LabelEncoder()
data.Road_surface_conditions =le16.fit_transform(data.Road_surface_conditions)

# %%
le17=LabelEncoder()
data.Light_conditions =le17.fit_transform(data.Light_conditions )

# %%
le18=LabelEncoder()
data.Weather_conditions =le18.fit_transform(data.Weather_conditions )

# %%
le19=LabelEncoder()
data.Type_of_collision=le19.fit_transform(data.Type_of_collision)

# %%
le20=LabelEncoder()
data.Vehicle_movement=le20.fit_transform(data.Vehicle_movement)

# %%
le21=LabelEncoder()
data.Casualty_class=le21.fit_transform(data.Casualty_class)

# %%
le22=LabelEncoder()
data.Sex_of_casualty =le22.fit_transform(data.Sex_of_casualty )

# %%
le23=LabelEncoder()
data.Age_band_of_casualty=le23.fit_transform(data.Age_band_of_casualty)

# %%
le24=LabelEncoder()
data.Casualty_severity=le24.fit_transform(data.Casualty_severity)

# %%
le25=LabelEncoder()
data.Work_of_casuality =le25.fit_transform(data.Work_of_casuality )

# %%
le26=LabelEncoder()
data.Fitness_of_casuality =le26.fit_transform(data.Fitness_of_casuality )

# %%
le27=LabelEncoder()
data.Pedestrian_movement =le27.fit_transform(data.Pedestrian_movement)

# %%
le28=LabelEncoder()
data.Cause_of_accident =le28.fit_transform(data.Cause_of_accident )

# %%
le29=LabelEncoder()
data.Accident_severity =le29.fit_transform(data.Accident_severity )

# %%
d=data.corr()

# %%
plt.figure(figsize=(30,10))
sns.heatmap(d,annot=True)
# Out:
# <Axes: >

# %%
ip=data.drop(['Accident_severity'],axis=1)

# %%
op=data['Accident_severity']

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2, random_state=42)

# %%
#standard scalar transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
alg1=LogisticRegression()
alg1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
yp=alg1.predict(x_test)

# %%
yp
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
df=pd.DataFrame({'y':list(y_test),'prediction':yp})

# %%
df
# Out:
#       y  prediction
# 0     2           2
# 1     2           2
# 2     1           2
# 3     2           2
# 4     2           2
# ...  ..         ...
# 2459  2           2
# 2460  2           2
# 2461  2           2
# 2462  2           2
# 2463  2           2
#
# [2464 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm=confusion_matrix(y_test,yp)
cm
# Out:
# array([[   0,    0,   37],
#        [   0,    0,  363],
#        [   0,    0, 2064]], dtype=int64)

# %%
cm1=ConfusionMatrixDisplay(cm)
cm1.plot()
plt.show()

# %% [markdown]
# from sklearn.metrics import accuracy_score
# acc=accuracy_score(y_test,yp)

# %%
print(acc)
# Out:
# 0.8376623376623377

# %% [markdown]
# from sklearn.naive_bayes import GaussianNB
# gb=GaussianNB()
# gb.fit(x_train,y_train)

# %%
yp1=gb.predict(x_test)

# %%
yp1
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
from sklearn.metrics import accuracy_score
acc1=accuracy_score(y_test,yp1)

# %%
print(acc1)
# Out:
# 0.823051948051948

# %% [markdown]
# from sklearn.neighbors import KNeighborsClassifier
# alg2= KNeighborsClassifier(n_neighbors=50)
# alg2.fit(x_train,y_train)

# %%
yp2=alg2.predict(x_test)

# %%
yp2
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
from sklearn.metrics import accuracy_score
acc2=accuracy_score(y_test,yp2)

# %%
print(acc2)
# Out:
# 0.8376623376623377
